# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot  as plt

# %%
runs= pd.read_csv("odi-batting.csv")
runs.head()
# Out:
#        Country            Player  Runs   MatchDate Weekday  \
# 0  Afghanistan  Mohammad Shahzad   118  16-02-2010     Tue
# 1  Afghanistan  Mohammad Shahzad   110  01-09-2009     Tue
# 2  Afghanistan  Mohammad Shahzad   100  16-08-2010     Mon
# 3  Afghanistan  Mohammad Shahzad    82  10-07-2010     Sat
# 4  Afghanistan  Mohammad Shahzad    57  01-07-2010     Thu
#
#                   Ground       Versus  Balls
# 0     Sharjah CA Stadium       Canada    121
# 1             VRA Ground  Netherlands    111
# 2  Cambusdoon New Ground     Scotland     72
# 3            Hazelaarweg  Netherlands    108
# 4    Sportpark Westvliet       Canada     57

# %%
runs_gte_100 = runs[runs.Runs >=100]

# %%
runs_gte_100.head()
# Out:
#         Country            Player  Runs   MatchDate Weekday  \
# 0   Afghanistan  Mohammad Shahzad   118  16-02-2010     Tue
# 1   Afghanistan  Mohammad Shahzad   110  01-09-2009     Tue
# 2   Afghanistan  Mohammad Shahzad   100  16-08-2010     Mon
# 62  Afghanistan   Noor Ali Zadran   114  16-02-2010     Tue
# 87  Afghanistan      Karim Sadiq    114  16-08-2010     Mon
#
#                    Ground       Versus  Balls
# 0      Sharjah CA Stadium       Canada    121
# 1              VRA Ground  Netherlands    111
# 2   Cambusdoon New Ground     Scotland     72
# 62     Sharjah CA Stadium       Canada    127
# 87  Cambusdoon New Ground     Scotland    108

# %%
def function(x):

# %%
x= runs_gte_100.pivot_table( index = 'Player',values=['Runs','Balls'], aggfunc = 'sum')

# %%
x['RR'] = round(x.Runs /x.Balls * 100,0)

# %%
x.sort_values(by='RR',ascending=False)
# Out:
#                        Balls  Runs     RR
# Player
# Mark V Boucher            68   147  216.0
# Basit Ali                 79   127  161.0
# Shahid Afridi            408   654  160.0
# John M Davison            76   111  146.0
# Umar Akmal                72   102  142.0
# Jacob D P Oram            72   101  140.0
# Bradley J Hodge           89   123  138.0
# Yusuf K Pathan           166   228  137.0
# Kevin J O'Brien          188   255  136.0
# David J Hussey            83   111  134.0
# Xavier M Marshall        118   157  133.0
# Ricardo L Powell          93   124  133.0
# Sanjay V Manjrekar        82   105  128.0
# Kapil Dev                138   175  127.0
# Darren J Reekers          82   104  127.0
# Charles K Coventry       156   194  124.0
# Jesse D Ryder            173   212  123.0
# Paul R Stirling          408   500  123.0
# Michael E K Hussey       265   322  122.0
# Abraham B de Villiers   1033  1246  121.0
# Marlon N Samuels         174   208  120.0
# ...

# %%
runs_gte_100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1161 entries, 0 to 49237
# Data columns (total 8 columns):
# Country      1161 non-null object
# Player       1161 non-null object
# Runs         1161 non-null int64
# MatchDate    1161 non-null object
# Weekday      1161 non-null object
# Ground       1161 non-null object
# Versus       1161 non-null object
# Balls        1161 non-null int64
# dtypes: int64(2), object(6)
# memory usage: 81.6+ KB

# %%
def getCenturyColumn(x):
    return 1 if x>= 100 else 0

# %%
runs['is_centurary'] = runs.Runs.apply(lambda x: getCenturyColumn(x))

# %%
runs['year'] = runs.MatchDate.apply(lambda x: x[-4:])

# %%
runs[(runs.Country =="India") & (runs['is_centurary']==1)].pivot_table(index='year',aggfunc="sum")
# Out:
#       Balls  Runs  is_centurary
# year
# 1983    138   175             1
# 1984    407   309             3
# 1986    224   204             2
# 1987    406   440             4
# 1988    571   523             5
# 1989    217   209             2
# 1990    372   313             3
# 1991    231   214             2
# 1992    148   114             1
# 1993    309   234             2
# 1994    915   758             7
# 1995    107   112             1
# 1996   1017   913             8
# 1997    816   771             7
# 1998   2192  2135            18
# 1999   2003  1998            15
# 2000   1389  1252            10
# 2001   1042  1047             9
# 2002   1007  1062             9
# 2003   1206  1130            10
# 2004    835   831             7
# 2005   1330  1307            11
# 2006    532   556             5
# 2007    488   575             5
# 2008   1007  1140            10
# 2009   1486  1749            13
# 2010   1330  1444            12
# 2011    823   943             8
